# %% [markdown]
# ### Python para análise fundamentalista
# - Income Statement = DRE
# - Cash Flow = Fluxo de caixa
# - Balance Sheet = Balanço patrimonial
# - Atividade de insiders
# - Informações anuais e trimestrais

# %% [markdown]
# ### Bibliotecas

# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# ### Escolhendo ativo

# %%
ativo = yf.Ticker("AAPL")

ativo
# Out:
# yfinance.Ticker object <AAPL>

# %% [markdown]
# ### Informações gerais

# %%
ativo.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
ativo.info["dividendYield"]
# Out:
# 0.0047999998

# %% [markdown]
# ### Balance Sheet
# #### Balanço Patrimonial

# %%
default_max_rows = pd.options.display.max_rows
default_max_rows
# Out:
# 60

# %%
pd.set_option("display.max_rows", None)

ativo.balance_sheet
# Out:
#                                                         2023-09-30  \
# Treasury Shares Number                                         0.0
# Ordinary Shares Number                               15550061000.0
# Share Issued                                         15550061000.0
# Net Debt                                             81123000000.0
# Total Debt                                          123930000000.0
# Tangible Book Value                                  62146000000.0
# Invested Capital                                    173234000000.0
# Working Capital                                      -1742000000.0
# Net Tangible Assets                                  62146000000.0
# Capital Lease Obligations                            12842000000.0
# Common Stock Equity                                  62146000000.0
# Total Capitalization                                157427000000.0
# Total Equity Gross Minority Interest                 62146000000.0
# ...

# %%
ativo.get_balancesheet(freq="quarterly")
# Out:
#                                                 2024-03-31      2023-12-31  \
# TreasurySharesNumber                                   NaN             0.0
# OrdinarySharesNumber                         15337686000.0   15460223000.0
# ShareIssued                                  15337686000.0   15460223000.0
# NetDebt                                      71895000000.0   67280000000.0
# TotalDebt                                   104590000000.0  108040000000.0
# ...                                                    ...             ...
# CashCashEquivalentsAndShortTermInvestments   67150000000.0   73100000000.0
# OtherShortTermInvestments                    34455000000.0   32340000000.0
# CashAndCashEquivalents                       32695000000.0   40760000000.0
# CashEquivalents                               4468000000.0   11218000000.0
# CashFinancial                                28227000000.0   29542000000.0
#
# ...

# %% [markdown]
# #### Income Statement
# demonstração de resultados

# %%
ativo.incomestmt
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.147
# Normalized EBITDA                                   129188000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              129188000000.0
# EBIT                                                117669000000.0
# Net Interest Income                                   -183000000.0
# Interest Expense                                      3933000000.0
# Interest Income                                       3750000000.0
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %% [markdown]
# #### Cash Flow

# %%
ativo.cash_flow
# Out:
#                                                     2023-09-30  \
# Free Cash Flow                                   99584000000.0
# Repurchase Of Capital Stock                     -77550000000.0
# Repayment Of Debt                               -11151000000.0
# Issuance Of Debt                                  5228000000.0
# Issuance Of Capital Stock                                  NaN
# Capital Expenditure                             -10959000000.0
# Interest Paid Supplemental Data                   3803000000.0
# Income Tax Paid Supplemental Data                18679000000.0
# End Cash Position                                30737000000.0
# Beginning Cash Position                          24977000000.0
# Changes In Cash                                   5760000000.0
# Financing Cash Flow                            -108488000000.0
# Cash Flow From Continuing Financing Activities -108488000000.0
# Net Other Financing Charges                      -6012000000.0
# ...

# %% [markdown]
# #### Insider

# %%
ativo.insider_purchases
# Out:
#        Insider Purchases Last 6m     Shares  Trans
# 0                      Purchases     659615      7
# 1                          Sales     598229      8
# 2    Net Shares Purchased (Sold)      61386     15
# 3      Total Insider Shares Held  800345728   <NA>
# 4  % Net Shares Purchased (Sold)          0   <NA>
# 5                   % Buy Shares          0   <NA>
# 6                  % Sell Shares          0   <NA>

# %% [markdown]
# #### Dividendos

# %%
ativo.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# 2023-11-10 00:00:00-05:00    0.240000
# 2024-02-09 00:00:00-05:00    0.240000
# 2024-05-10 00:00:00-04:00    0.250000
# Name: Dividends, Length: 83, dtype: float64

# %% [markdown]
# #### Quem possui a ação

# %%
ativo.insider_transactions
# Out:
#      Shares       Value URL                                      Text  \
# 0     75000  14368500.0               Sale at price 191.58 per share.
# 1      4999    951785.0               Sale at price 190.40 per share.
# 2      1850         0.0           Stock Gift at price 0.00 per share.
# 3      8119         NaN
# 4     59162  10188880.0               Sale at price 172.22 per share.
# ..      ...         ...  ..                                       ...
# 145   17000   1877109.0      Sale at price 109.22 - 110.99 per share.
# 146   14840   1800686.0               Sale at price 121.34 per share.
# 147   31200   3737869.0      Sale at price 119.58 - 120.14 per share.
# 148   23652         NaN
# 149   66532         NaN
#
#                 Insider                 Position Transaction Start Date  \
# 0     LEVINSON ARTHUR D                 Director             2024-05-30
# 1     KONDO CHRISTOPHER                  Officer             2024-05-15
# ...

# %%
print(pd.options.display.max_rows)
pd.options.display.max_rows = default_max_rows
print(pd.options.display.max_rows)
# Out:
# None
# 60
